# %% [markdown]
# ### PrepareWorkSpaces

# %%
import sys
import os
import winreg
import subprocess
from PySide6.QtWidgets import (QApplication, QMainWindow, QPushButton, 
                               QVBoxLayout, QWidget, QMessageBox, QLabel)
from PySide6.QtCore import Qt

# Global Configuration
languages = ["zh", "en", "jp", "kr"]

# 后续把键名改为游戏的英文名更直观不用game+数字了 更好的可写个Json文件来存储游戏名称和对应的语言
GameNames = {
    "game1": dict.fromkeys(languages, ""),
    "game2": dict.fromkeys(languages, ""),
    "game3": dict.fromkeys(languages, ""),
    "game4": dict.fromkeys(languages, ""),
    "game5": dict.fromkeys(languages, ""),
    "game6": dict.fromkeys(languages, ""),
    "game7": dict.fromkeys(languages, ""),
    "game8": dict.fromkeys(languages, ""),
}

# Default
GameNames["game1"]["zh"] = "鸣潮"
GameNames["game2"]["zh"] = "崩坏：星穹铁道"
GameNames["game3"]["zh"] = "原神"
GameNames["game4"]["zh"] = "绝区零"
GameNames["game5"]["zh"] = "明日方舟：终末地"
GameNames["game6"]["zh"] = "战双帕弥什"
GameNames["game7"]["zh"] = "异环"
GameNames["game8"]["zh"] = "幻塔"

# Other Languages
GameNames["game1"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game2"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game3"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game4"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game5"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game6"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game7"].update({
    "en": "",
    "jp": "",
    "kr": ""
})
GameNames["game8"].update({
    "en": "",
    "jp": "",
    "kr": ""
})

# 取值示例：game_name = GameNames["game1"]["zh"]

# List of registry paths to check for installed games （兼容32位和64位系统）
Registry_HKCU = winreg.HKEY_CURRENT_USER
Registry_HKLM = winreg.HKEY_LOCAL_MACHINE
Registry_paths = [
        r"SOFTWARE\Microsoft\Windows\CurrentVersion\Uninstall",
        r"SOFTWARE\WOW6432Node\Microsoft\Windows\CurrentVersion\Uninstall"
    ]
